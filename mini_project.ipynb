# %%
import requests
from bs4 import BeautifulSoup

useless_flipkart=[
    'Buy',
    'Products',
    'Online',
    'Buy Products Online at Best Price in India - All Categories | Flipkart.com',
    'Explore',
    'CartFiltersCATEGORIES',
    '&',
    'Accessories'
]

search=input(' Search Prodect ')

amazon_url='https://www.amazon.in/s?k='+search+'&ref=nb_sb_noss_2'
flipkart_url='https://www.flipkart.com/search?q='+search+'&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
reliance_url='https://www.reliancedigital.in/search?q='+search+':relevance'

header={"User_Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36'}

amazon_page=requests.get(amazon_url,headers=header)
flipkart_page=requests.get(flipkart_url,headers=header)
reliance_page=requests.get(reliance_url,headers=header)

amazon_code=BeautifulSoup(amazon_page.content,'html.parser')
flipkart_code=BeautifulSoup(flipkart_page.content,'html.parser')
reliance_code=BeautifulSoup(reliance_page.content,'html.parser')

temp=flipkart_code.get_text()
for i in range (0,len(useless_flipkart)):
    temp.replace(useless_flipkart[i],"")

print(amazon_url)
#print(amazon_code.get_text())
print(flipkart_url)
print(temp)
print(reliance_url)
#print(reliance_code)
# Out:
#  Search Prodect phone
# https://www.amazon.in/s?k=phone&ref=nb_sb_noss_2
# https://www.flipkart.com/search?q=phone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Phone - Buy Products Online at Best Price in India - All Categories | Flipkart.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Explore PlusLogin More CartFiltersCATEGORIESMobiles & AccessoriesMobilesPrice............Min₹2000₹4000₹7000₹10000₹13000₹16000₹20000₹25000₹30000₹50000to₹2000₹4000₹7000₹10000₹13000₹16000₹20000₹25000₹30000₹50000₹50000+?RAM6 GB & Above4 GB3 GB2 GB1 GB512 MB - 1 GBLess than 512 MBBrandPOCORealmeInfinixMotorolaSamsungMi304 MORECustomer Ratings4★ & above3★ & above2★ & above1★ & aboveInternal StorageBattery CapacityOperating SystemNetwork TypeScreen SizeSim TypePrimary CameraSecondary CameraOffersBank OfferBuy More, Save MoreNo Cost EMISpecial PriceProcessor BrandSpecialityResolution TypeTypeOperating System Version NameAvailabilityClock SpeedFeaturesNumber of CoresBudgetNeed help?Help me decideHomeMobiles & AccessoriesMobilesShowing 1 – 24 of 10,927 results for "phone"Sort ByRelevancePopularityPrice -- Low to HighPrice -- High to LowNewest FirstComing SoonAdd to CompareRealme C11 (Rich Grey, 32 GB)4.473,043 Ratings & 5,174 Reviews2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP | 5MP Front Camera5000 mAh BatteryMediatek Helio G35 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories₹7,499₹8,99916% offComing SoonAdd to CompareRealme C11 (Rich Green, 32 GB)4.473,043 Ratings & 5,174 Reviews2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP | 5MP Front Camera5000 mAh BatteryMediatek Helio G35 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories₹7,499₹8,99916% offComing SoonAdd to CompareInfinix Hot 9 Pro (Violet, 64 GB)4.523,735 Ratings & 1,819 Reviews4 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.76 cm (6.6 inch) HD+ Display48 MP + 2 MP + 2 MP + Low Light Sensor | 8MP Front Camera5000 mAh Li-ion Polymer BatteryMediaTek Helio P22 (64 bit) Processor1 Year Warranty on Phone, 6 Months Warranty on Accessories₹10,499₹12,99919% offAdd to CompareRedmi 8 (Ruby Red, 64 GB)4.47,55,614 Ratings & 55,645 Reviews4 GB RAM | 64 GB ROM | Expandable Upto 512 GB15.8 cm (6.22 inch) HD+ Display12MP + 2MP | 8MP Front Camera5000 mAh BatteryQualcomm Snapdragon 439 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories₹9,999₹10,9999% offNo Cost EMIUpto ₹9,350 Off on ExchangeComing SoonAdd to CompareInfinix Hot 9 Pro (Ocean Wave, 64 GB)4.523,735 Ratings & 1,819 Reviews4 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.76 cm (6.6 inch) HD+ Display48 MP + 2 MP + 2 MP + Low Light Sensor | 8MP Front Camera5000 mAh Li-ion Polymer BatteryMediaTek Helio P22 (64 bit) Processor1 Year Warranty on Phone, 6 Months Warranty on Accessories₹10,499₹12,99919% offComing SoonAdd to ComparePOCO M2 Pro (Out of the Blue, 64 GB)4.55,004 Ratings & 564 Reviews4 GB RAM | 64 GB ROM | Expandable Upto 512 GB16.94 cm (6.67 inch) Full HD+ Display48MP + 8MP + 5MP + 2MP | 16MP Front Camera5000 mAh Lithium-ion Polymer BatteryQualcomm Snapdragon 720G Processor1 Year for Handset, 6 Months for Accessories₹13,999₹16,99917% offComing SoonAdd to CompareInfinix Smart 4 Plus (Ocean Wave, 32 GB)4.419,541 Ratings & 1,810 Reviews3 GB RAM | 32 GB ROM | Expandable Upto 256 GB17.32 cm (6.82 inch) HD+ Display13MP + Depth Sensor | 8MP Front Camera6000 mAh Lithium-ion Polymer BatteryMediatek Helio A25 Processor1 Year on Handset and 6 Months on Accessories₹7,999₹9,99920% offComing SoonAdd to CompareInfinix Smart 4 Plus (Midnight Black, 32 GB)4.419,541 Ratings & 1,810 Reviews3 GB RAM | 32 GB ROM | Expandable Upto 256 GB17.32 cm (6.82 inch) HD+ Display13MP + Depth Sensor | 8MP Front Camera6000 mAh Lithium-ion Polymer BatteryMediatek Helio A25 Processor1 Year on Handset and 6 Months on Accessories₹7,999₹9,99920% offComing SoonAdd to CompareInfinix Smart 4 Plus (Violet, 32 GB)4.419,541 Ratings & 1,810 Reviews3 GB RAM | 32 GB ROM | Expandable Upto 256 GB17.32 cm (6.82 inch) HD+ Display13MP + Depth Sensor | 8MP Front Camera6000 mAh Lithium-ion Polymer BatteryMediatek Helio A25 Processor1 Year on Handset and 6 Months on Accessories₹7,999₹9,99920% offAdd to Compa ...
#  Buildings Alyssa, Begonia &
#  Clove Embassy Tech Village,
#  Outer Ring Road, Devarabeesanahalli Village,
#  Bengaluru, 560103,
#  Karnataka, India
# Registered Office Address:Flipkart Internet Private Limited,
#  Buildings Alyssa, Begonia &
#  Clove Embassy Tech Village,
#  Outer Ring Road, Devarabeesanahalli Village,
#  Bengaluru, 560103,
#  Karnataka, India
#  CIN : U51109KA2012PTC066107
#  Telephone: 1800 208 9898
# Sell On FlipkartAdvertiseGift CardsHelp Center© 2007-2020 Flipkart.comBack to top
#
#
#
#
#
#
#
#
# https://www.reliancedigital.in/search?q=phone:relevance
